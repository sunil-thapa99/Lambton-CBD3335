# %%
import pandas as pd

# %%
df = pd.read_csv('df_dev.csv')

# %%
df.head(5)
# Out:
#       ID  credit_limit card_type  gender  education  age  pay_status_1  \
# 0  10000        310000      VISA       1          3   32             0
# 1  10001         10000       NaN       2          3   49            -1
# 2  10002         50000    MASTER       1          2   30            -1
# 3  10003         80000      VISA       2          3   52             2
# 4  10004        270000       NaN       1          1   36             1
#
#    pay_status_2  pay_status_3  pay_status_4  ...  bill_amount_2  \
# 0             0             0             0  ...         152397
# 1            -1            -2            -1  ...           -358
# 2            -1            -1             0  ...              0
# 3             2             3             3  ...          39448
# 4             2             0             0  ...          17228
#
#    bill_amount_3  bill_amount_4  bill_amount_5  pay_amount_1  pay_amount_2  \
# ...

# %%
df.tail(5)
# Out:
#           ID  credit_limit card_type  gender  education  age  pay_status_1  \
# 19995  29995        310000      VISA       2          1   45             0
# 19996  29996         90000    MASTER       2          2   25            -1
# 19997  29997        100000      VISA       2          2   23             0
# 19998  29998        170000      VISA       2          2   27            -1
# 19999  29999         30000       NaN       2          3   24            -1
#
#        pay_status_2  pay_status_3  pay_status_4  ...  bill_amount_2  \
# 19995             0             0             0  ...          93351
# 19996            -1            -1            -1  ...           4300
# 19997             0             0             0  ...           7954
# 19998            -1            -1             0  ...          -1020
# 19999            -1             0            -1  ...          29393
#
#        bill_amount_3  bill_amount_4  bill_amount_5  pay_amount_1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             20000 non-null  int64
#  1   credit_limit   20000 non-null  int64
#  2   card_type      13370 non-null  object
#  3   gender         20000 non-null  int64
#  4   education      20000 non-null  int64
#  5   age            20000 non-null  int64
#  6   pay_status_1   20000 non-null  int64
#  7   pay_status_2   20000 non-null  int64
#  8   pay_status_3   20000 non-null  int64
#  9   pay_status_4   20000 non-null  int64
#  10  pay_status_5   20000 non-null  int64
#  11  bill_amount_1  20000 non-null  int64
#  12  bill_amount_2  20000 non-null  int64
#  13  bill_amount_3  20000 non-null  int64
#  14  bill_amount_4  20000 non-null  int64
#  15  bill_amount_5  20000 non-null  int64
#  16  pay_amount_1   20000 non-null  int64
#  17  pay_amount_2   20000 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['ID', 'credit_limit', 'card_type', 'gender', 'education', 'age',
#        'pay_status_1', 'pay_status_2', 'pay_status_3', 'pay_status_4',
#        'pay_status_5', 'bill_amount_1', 'bill_amount_2', 'bill_amount_3',
#        'bill_amount_4', 'bill_amount_5', 'pay_amount_1', 'pay_amount_2',
#        'pay_amount_3', 'pay_amount_4', 'pay_amount_5', 'Default'],
#       dtype='object')

# %%
df.shape
# Out:
# (20000, 22)

# %%
cols = df.columns.to_list()

# %%
for col in cols:
    if df[col].dtype == 'int64':
        print(df[col].mean())
# Out:
# 19999.5
# 167259.6
# 1.6042
# 1.8504
# 36.4892
# -0.01095
# -0.1373
# -0.16915
# -0.222
# -0.26795
# 51608.73115
# 49575.2246
# 47380.97135
# 43529.5058
# 40663.3279
# 5716.6262
# 5869.71555
# 5171.56975
# 4909.82925
# 4868.29965
# 0.2252

# %%
numeric_columns = df.select_dtypes(include='number')

# %%
numeric_columns
# Out:
#           ID  credit_limit  gender  education  age  pay_status_1  \
# 0      10000        310000       1          3   32             0
# 1      10001         10000       2          3   49            -1
# 2      10002         50000       1          2   30            -1
# 3      10003         80000       2          3   52             2
# 4      10004        270000       1          1   36             1
# ...      ...           ...     ...        ...  ...           ...
# 19995  29995        310000       2          1   45             0
# 19996  29996         90000       2          2   25            -1
# 19997  29997        100000       2          2   23             0
# 19998  29998        170000       2          2   27            -1
# 19999  29999         30000       2          3   24            -1
#
#        pay_status_2  pay_status_3  pay_status_4  pay_status_5  ...  \
# 0                 0             0             0             0  ...
# ...

# %%
num_col_list = numeric_columns.columns.to_list()

# %%
for col in num_col_list:
    print(df[col].mean())
# Out:
# 19999.5
# 167259.6
# 1.6042
# 1.8504
# 36.4892
# -0.01095
# -0.1373
# -0.16915
# -0.222
# -0.26795
# 51608.73115
# 49575.2246
# 47380.97135
# 43529.5058
# 40663.3279
# 5716.6262
# 5869.71555
# 5171.56975
# 4909.82925
# 4868.29965
# 0.2252

# %%
df.describe()
# Out:
#                  ID   credit_limit        gender     education          age  \
# count  20000.000000   20000.000000  20000.000000  20000.000000  20000.00000
# mean   19999.500000  167259.600000      1.604200      1.850400     36.48920
# std     5773.647028  129568.094847      0.489034      0.793569      9.30501
# min    10000.000000   10000.000000      1.000000      0.000000     21.00000
# 25%    14999.750000   50000.000000      1.000000      1.000000     29.00000
# 50%    19999.500000  140000.000000      2.000000      2.000000     35.00000
# 75%    24999.250000  240000.000000      2.000000      2.000000     42.00000
# max    29999.000000  800000.000000      2.000000      6.000000     81.00000
#
#        pay_status_1  pay_status_2  pay_status_3  pay_status_4  pay_status_5  \
# count  20000.000000  20000.000000  20000.000000  20000.000000   20000.00000
# mean      -0.010950     -0.137300     -0.169150     -0.222000      -0.26795
# ...

# %%
df.isna().mean() * 100
# Out:
# ID                0.00
# credit_limit      0.00
# card_type        33.15
# gender            0.00
# education         0.00
# age               0.00
# pay_status_1      0.00
# pay_status_2      0.00
# pay_status_3      0.00
# pay_status_4      0.00
# pay_status_5      0.00
# bill_amount_1     0.00
# bill_amount_2     0.00
# bill_amount_3     0.00
# bill_amount_4     0.00
# bill_amount_5     0.00
# pay_amount_1      0.00
# pay_amount_2      0.00
# pay_amount_3      0.00
# pay_amount_4      0.00
# pay_amount_5      0.00
# Default           0.00
# dtype: float64

# %%
data = [10, 20, 30, 40, 50, 60, 70]
df2 = pd.DataFrame(data, columns=['Numbers'])

df2.head()
# Out:
#    Numbers
# 0       10
# 1       20
# 2       30
# 3       40
# 4       50

# %%
person = {'first_name': ['Sunil', 'Samir', 'Sushil'], 
            'last_name': ['Thapa', 'Khanal', 'Basi'],
            'email': ['sunil@gmail.com', 'samir@gmail.com', 'sushil@gmail.com']}

# %%
df3 = pd.DataFrame(person)
df3
# Out:
#   first_name last_name             email
# 0      Sunil     Thapa   sunil@gmail.com
# 1      Samir    Khanal   samir@gmail.com
# 2     Sushil      Basi  sushil@gmail.com

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df3['first_name'])
# Out:
# pandas.core.series.Series

# %%
df[['age', 'credit_limit']]
# Out:
#        age  credit_limit
# 0       32        310000
# 1       49         10000
# 2       30         50000
# 3       52         80000
# 4       36        270000
# ...    ...           ...
# 19995   45        310000
# 19996   25         90000
# 19997   23        100000
# 19998   27        170000
# 19999   24         30000
#
# [20000 rows x 2 columns]

# %%
df.loc[2]
# Out:
# ID                10002
# credit_limit      50000
# card_type        MASTER
# gender                1
# education             2
# age                  30
# pay_status_1         -1
# pay_status_2         -1
# pay_status_3         -1
# pay_status_4          0
# pay_status_5         -1
# bill_amount_1       430
# bill_amount_2         0
# bill_amount_3     46257
# bill_amount_4     45975
# bill_amount_5      1300
# pay_amount_1          0
# pay_amount_2      46257
# pay_amount_3       2200
# pay_amount_4       1300
# pay_amount_5      43987
# Default               0
# Name: 2, dtype: object

# %%
data = {'Name': ['Tom', 'Jack', 'nick'], 'marks': [99, 98, 95]}

df4 = pd.DataFrame(data, index=['rank1', 'rank2', 'rank3'])
df4
# Out:
#        Name  marks
# rank1   Tom     99
# rank2  Jack     98
# rank3  nick     95

# %%
df4.loc['rank3']
# Out:
# Name     nick
# marks      95
# Name: rank3, dtype: object

# %%
df4.iloc[1:]
# Out:
#        Name  marks
# rank2  Jack     98
# rank3  nick     95

# %%
df.iloc[5:8]
# Out:
#       ID  credit_limit card_type  gender  education  age  pay_status_1  \
# 5  10005        140000    MASTER       2          3   32             0
# 6  10006        200000       NaN       1          2   26            -1
# 7  10007        150000       NaN       1          2   37            -1
#
#    pay_status_2  pay_status_3  pay_status_4  ...  bill_amount_2  \
# 5             0             0             0  ...          96304
# 6            -1             0             0  ...          11817
# 7             0             0             0  ...          63265
#
#    bill_amount_3  bill_amount_4  bill_amount_5  pay_amount_1  pay_amount_2  \
# 5          98007          82227          65000          4700          4505
# 6          14225          16017          12613         12957          3884
# 7          64131          64942          61803          2500          2500
#
#    pay_amount_3  pay_amount_4  pay_amount_5  Default
# 5         12906             0          2210        0
# ...

# %%
df.loc[5:8]
# Out:
#       ID  credit_limit card_type  gender  education  age  pay_status_1  \
# 5  10005        140000    MASTER       2          3   32             0
# 6  10006        200000       NaN       1          2   26            -1
# 7  10007        150000       NaN       1          2   37            -1
# 8  10008         20000       NaN       2          2   24             0
#
#    pay_status_2  pay_status_3  pay_status_4  ...  bill_amount_2  \
# 5             0             0             0  ...          96304
# 6            -1             0             0  ...          11817
# 7             0             0             0  ...          63265
# 8             0             0             0  ...          17960
#
#    bill_amount_3  bill_amount_4  bill_amount_5  pay_amount_1  pay_amount_2  \
# 5          98007          82227          65000          4700          4505
# 6          14225          16017          12613         12957          3884
# ...

# %%
df.loc[1:3, ['age', 'pay_status_1']]
# Out:
#    age  pay_status_1
# 1   49            -1
# 2   30            -1
# 3   52             2

# %%
df.loc[1:3, 'gender': 'pay_status_1']
# Out:
#    gender  education  age  pay_status_1
# 1       2          3   49            -1
# 2       1          2   30            -1
# 3       2          3   52             2
